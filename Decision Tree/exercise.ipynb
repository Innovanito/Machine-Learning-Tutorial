# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
inputs = df.drop('Survived', axis='columns')
output = df['Survived']

# %% [markdown]
# Delete the column value of PassengerId,Name,Ticket,Cabin,Embarked
#
#
# Then us LabelEncoder and fit_transform to chagne Sex and Embarked values into number

# %%
inputs_2 = inputs.drop(['PassengerId','Name', 'Ticket', 'Cabin', 'Fare'], axis='columns')
inputs_2
# Out:
#      Pclass     Sex   Age  SibSp  Parch Embarked
# 0         3    male  22.0      1      0        S
# 1         1  female  38.0      1      0        C
# 2         3  female  26.0      0      0        S
# 3         1  female  35.0      1      0        S
# 4         3    male  35.0      0      0        S
# ..      ...     ...   ...    ...    ...      ...
# 886       2    male  27.0      0      0        S
# 887       1  female  19.0      0      0        S
# 888       3  female   NaN      1      2        S
# 889       1    male  26.0      0      0        C
# 890       3    male  32.0      0      0        Q
#
# [891 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_sex = LabelEncoder()
le_embarked = LabelEncoder()

# %%
inputs_2['Sex_n']=le_sex.fit_transform(inputs_2['Sex'])
inputs_2['Embarked_n']=le_embarked.fit_transform(inputs_2['Embarked'])

# %%
inputs_2[:20]
# Out:
#     Pclass     Sex   Age  SibSp  Parch Embarked  Sex_n  Embarked_n
# 0        3    male  22.0      1      0        S      1           2
# 1        1  female  38.0      1      0        C      0           0
# 2        3  female  26.0      0      0        S      0           2
# 3        1  female  35.0      1      0        S      0           2
# 4        3    male  35.0      0      0        S      1           2
# 5        3    male   NaN      0      0        Q      1           1
# 6        1    male  54.0      0      0        S      1           2
# 7        3    male   2.0      3      1        S      1           2
# 8        3  female  27.0      0      2        S      0           2
# 9        2  female  14.0      1      0        C      0           0
# 10       3  female   4.0      1      1        S      0           2
# 11       1  female  58.0      0      0        S      0           2
# 12       3    male  20.0      0      0        S      1           2
# ...

# %%
inputs_2 = inputs_2.drop(['Sex', 'Embarked'], axis='columns')
inputs_2[:20]
# Out:
#     Pclass   Age  SibSp  Parch  Sex_n  Embarked_n
# 0        3  22.0      1      0      1           2
# 1        1  38.0      1      0      0           0
# 2        3  26.0      0      0      0           2
# 3        1  35.0      1      0      0           2
# 4        3  35.0      0      0      1           2
# 5        3   NaN      0      0      1           1
# 6        1  54.0      0      0      1           2
# 7        3   2.0      3      1      1           2
# 8        3  27.0      0      2      0           2
# 9        2  14.0      1      0      0           0
# 10       3   4.0      1      1      0           2
# 11       1  58.0      0      0      0           2
# 12       3  20.0      0      0      1           2
# 13       3  39.0      1      5      1           2
# 14       3  14.0      0      0      0           2
# 15       2  55.0      0      0      0           2
# 16       3   2.0      4      1      1           1
# 17       2   NaN      0      0      1           2
# ...

# %%
inputs_2
# Out:
#      Pclass   Age  SibSp  Parch  Sex_n  Embarked_n
# 0         3  22.0      1      0      1           2
# 1         1  38.0      1      0      0           0
# 2         3  26.0      0      0      0           2
# 3         1  35.0      1      0      0           2
# 4         3  35.0      0      0      1           2
# ..      ...   ...    ...    ...    ...         ...
# 886       2  27.0      0      0      1           2
# 887       1  19.0      0      0      0           2
# 888       3   NaN      1      2      0           2
# 889       1  26.0      0      0      1           0
# 890       3  32.0      0      0      1           1
#
# [891 rows x 6 columns]

# %% [markdown]
# Now I have to deal with how to change NAN value into some value
#
# I think I am going to mean all the age value and replace NAN value into mean value

# %%
inputs_2 = inputs_2.fillna(0)
inputs_2[:20]
# Out:
#     Pclass   Age  SibSp  Parch  Sex_n  Embarked_n
# 0        3  22.0      1      0      1           2
# 1        1  38.0      1      0      0           0
# 2        3  26.0      0      0      0           2
# 3        1  35.0      1      0      0           2
# 4        3  35.0      0      0      1           2
# 5        3   0.0      0      0      1           1
# 6        1  54.0      0      0      1           2
# 7        3   2.0      3      1      1           2
# 8        3  27.0      0      2      0           2
# 9        2  14.0      1      0      0           0
# 10       3   4.0      1      1      0           2
# 11       1  58.0      0      0      0           2
# 12       3  20.0      0      0      1           2
# 13       3  39.0      1      5      1           2
# 14       3  14.0      0      0      0           2
# 15       2  55.0      0      0      0           2
# 16       3   2.0      4      1      1           1
# 17       2   0.0      0      0      1           2
# ...

# %%
inputs_2.mean()
# Out:
# Pclass         2.308642
# Age           23.799293
# SibSp          0.523008
# Parch          0.381594
# Sex_n          0.647587
# Embarked_n     1.538721
# dtype: float64

# %%
inputs_2.median()
# Out:
# Pclass         3.0
# Age           24.0
# SibSp          0.0
# Parch          0.0
# Sex_n          1.0
# Embarked_n     2.0
# dtype: float64

# %%
inputs_2['Age'] = inputs_2['Age'].replace(0,inputs_2['Age'].mean())
inputs_2[:20]
# Out:
#     Pclass        Age  SibSp  Parch  Sex_n  Embarked_n
# 0        3  22.000000      1      0      1           2
# 1        1  38.000000      1      0      0           0
# 2        3  26.000000      0      0      0           2
# 3        1  35.000000      1      0      0           2
# 4        3  35.000000      0      0      1           2
# 5        3  23.799293      0      0      1           1
# 6        1  54.000000      0      0      1           2
# 7        3   2.000000      3      1      1           2
# 8        3  27.000000      0      2      0           2
# 9        2  14.000000      1      0      0           0
# 10       3   4.000000      1      1      0           2
# 11       1  58.000000      0      0      0           2
# 12       3  20.000000      0      0      1           2
# 13       3  39.000000      1      5      1           2
# 14       3  14.000000      0      0      0           2
# 15       2  55.000000      0      0      0           2
# ...

# %%
inputs_2['Age'][:20].interpolate()
# Out:
# 0     22.000000
# 1     38.000000
# 2     26.000000
# 3     35.000000
# 4     35.000000
# 5     23.799293
# 6     54.000000
# 7      2.000000
# 8     27.000000
# 9     14.000000
# 10     4.000000
# 11    58.000000
# 12    20.000000
# 13    39.000000
# 14    14.000000
# 15    55.000000
# 16     2.000000
# 17    23.799293
# 18    31.000000
# 19    23.799293
# Name: Age, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs_2, output, test_size=0.2)

# %%
len(X_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.7988826815642458
